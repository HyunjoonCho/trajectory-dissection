# %%
import pandas as pd
import ast

# %%
# Function name mapping for readability
name_mapping = {
    'get_covered_packages': 'package',
    'get_failing_tests_covered_classes': 'class',
    'get_failing_tests_covered_methods_for_class': 'method',
    'get_code_snippet': 'snippet',
    'get_comments': 'comment'
}

def shorten_pattern(pattern_tuple):
    """Convert long function names to short versions"""
    return ' -> '.join([name_mapping.get(func, func) for func in pattern_tuple])

# %%
n = 4 # n-gram
benchmarks = ['d4j', 'bip']
models = ['llama3', 'llama3.1', 'mistral-nemo', 'qwen2.5-coder']

for bm in benchmarks:
    for model in models:
        correlation_file = f'./correlation/autofl/{n}-gram/{bm}/{model}/correlation.csv'
        df = pd.read_csv(correlation_file)
        df['pattern'] = df['pattern'].apply(ast.literal_eval)
        df['short_pattern'] = df['pattern'].apply(shorten_pattern)

        top_5_high = df.sort_values(by='correlation', ascending=False).head(5)
        top_5_low = df.sort_values(by='correlation', ascending=True).head(5)
        print(f"=================={bm}: {model}==================")
        print("=== Top 5 high ===")
        print(top_5_high[['short_pattern', 'correlation', 'p-value']])
        print("=== Top 5 low ===")
        print(top_5_low[['short_pattern', 'correlation', 'p-value']])
# Out:
# ==================d4j: llama3==================
# === Top 5 high ===
#                               short_pattern  correlation       p-value
# 0     class -> method -> snippet -> comment     0.124546  1.119029e-13
# 2   method -> snippet -> snippet -> snippet     0.087701  1.800158e-07
# 8  snippet -> snippet -> snippet -> comment     0.076909  4.770552e-06
# 6   method -> snippet -> comment -> snippet     0.070276  2.927467e-05
# 1     class -> method -> snippet -> snippet     0.068881  4.204946e-05
# === Top 5 low ===
#                             short_pattern  correlation   p-value
# 7   class -> method -> comment -> snippet    -0.034164  0.042389
# 3     class -> method -> method -> method    -0.034114  0.042694
# 21     class -> method -> method -> class    -0.030764  0.067610
# 29     class -> method -> class -> method    -0.028961  0.085357
# 9    method -> method -> method -> method    -0.028176  0.094178
# ==================d4j: llama3.1==================
# === Top 5 high ===
#                               short_pattern  correlation       p-value
# 3     class -> method -> snippet -> comment     0.116699  3.529086e-12
# 2     class -> method -> comment -> snippet     0.108485  1.031083e-10
# 0     class -> method -> snippet -> snippet     0.062639  1.960987e-04
# 8  snippet -> snippet -> snippet -> comment     0.054239  1.265126e-03
# 7  snippet -> snippet -> comment -> snippet     0.030156  7.321680e-02
# === Top 5 low ===
#                           short_pattern  correlation       p-value
# 5   class -> method -> method -> method    -0.175001  1.128907e-25
# 14  method -> method -> method -> class    -0.137745  2.030964e-16
# 10  method -> method -> class -> method    -0.130002  8.898627e-15
# 15   class -> method -> method -> class    -0.109673  6.426309e-11
# 18   method -> class -> method -> class    -0.106612  2.151621e-10
# ==================d4j: mistral-nemo==================
# === Top 5 high ===
#                                short_pattern  correlation   p-value
# 18   method -> snippet -> comment -> snippet     0.047584  0.004688
# 7   snippet -> comment -> snippet -> snippet     0.040091  0.017216
# 9   snippet -> snippet -> snippet -> comment     0.037828  0.024606
# 3      class -> method -> snippet -> comment     0.034237  0.041947
# 17   snippet -> snippet -> method -> snippet     0.029913  0.075566
# === Top 5 low ===
#                              short_pattern  correlation   p-value
# 10    class -> method -> method -> snippet    -0.066641  0.000074
# 12     class -> method -> method -> method    -0.047870  0.004445
# 1    class -> method -> snippet -> snippet    -0.046118  0.006134
# 16  method -> method -> snippet -> snippet    -0.044768  0.007809
# 19    method -> method -> method -> method    -0.038590  0.021857
# ==================d4j: qwen2.5-coder==================
# === Top 5 high ===
#                                short_pattern  correlation       p-value
# 4     class -> snippet -> comment -> snippet     0.096737  8.462171e-09
# 16  snippet -> comment -> snippet -> comment     0.055819  9.071700e-04
# 9   snippet -> comment -> snippet -> snippet     0.046238  6.002352e-03
# 3   snippet -> snippet -> snippet -> snippet     0.040685  1.563093e-02
# 21  comment -> snippet -> snippet -> snippet     0.036493  3.014841e-02
# === Top 5 low ===
#                             short_pattern  correlation   p-value
# 14   class -> method -> method -> snippet    -0.043864  0.009149
# 28   class -> method -> snippet -> method    -0.038265  0.022995
# 11    class -> method -> method -> method    -0.032359  0.054557
# 12  class -> snippet -> snippet -> method    -0.031320  0.062798
# 18  method -> method -> method -> snippet    -0.019349  0.250426
# ==================bip: llama3==================
# === Top 5 high ===
#                              short_pattern  correlation   p-value
# 3       class -> class -> class -> snippet     0.064286  0.000005
# 10    package -> class -> class -> snippet     0.057589  0.000046
# 22     class -> class -> snippet -> method     0.056320  0.000068
# 9      class -> class -> method -> snippet     0.042840  0.002449
# 24  package -> method -> method -> snippet     0.042369  0.002733
# === Top 5 low ===
#                         short_pattern  correlation   p-value
# 0    class -> class -> class -> class    -0.047422  0.000797
# 1  package -> class -> class -> class    -0.045503  0.001291
# 5  class -> class -> package -> class    -0.044305  0.001729
# 4  class -> class -> class -> package    -0.031299  0.026903
# 7  class -> package -> class -> class    -0.029158  0.039253
# ==================bip: llama3.1==================
# === Top 5 high ===
#                            short_pattern  correlation   p-value
# 4    class -> class -> method -> snippet     0.056617  0.000062
# 9   package -> class -> class -> snippet     0.046780  0.000937
# 3     class -> class -> class -> snippet     0.037666  0.007729
# 15  class -> class -> snippet -> snippet     0.034488  0.014738
# 16   class -> class -> snippet -> method     0.033336  0.018409
# === Top 5 low ===
#                          short_pattern  correlation       p-value
# 0     class -> class -> class -> class    -0.101930  5.028563e-13
# 11  class -> class -> package -> class    -0.064560  4.907156e-06
# 14  class -> package -> class -> class    -0.062539  9.626653e-06
# 1   package -> class -> class -> class    -0.059296  2.722708e-05
# 18  class -> class -> class -> package    -0.054181  1.265663e-04
# ==================bip: mistral-nemo==================
# === Top 5 high ===
#                                short_pattern  correlation   p-value
# 10      method -> method -> method -> method     0.020346  0.150295
# 3      package -> method -> method -> method     0.019111  0.176661
# 6      method -> method -> method -> snippet     0.013348  0.345333
# 5   package -> snippet -> snippet -> snippet     0.004517  0.749505
# 12    method -> snippet -> method -> snippet    -0.001271  0.928421
# === Top 5 low ===
#                               short_pattern  correlation       p-value
# 2   method -> snippet -> snippet -> snippet    -0.087898  4.790781e-10
# 0   package -> method -> snippet -> snippet    -0.053064  1.741120e-04
# 7    package -> method -> snippet -> method    -0.039224  5.538615e-03
# 8  snippet -> snippet -> snippet -> snippet    -0.032341  2.220468e-02
# 4    method -> method -> snippet -> snippet    -0.031193  2.740741e-02
# ==================bip: qwen2.5-coder==================
# === Top 5 high ===
#                             short_pattern  correlation   p-value
# 27    class -> class -> method -> snippet     0.018842  0.182813
# 25       class -> class -> class -> class     0.015382  0.276843
# 11  method -> method -> method -> snippet     0.015082  0.286318
# 26    package -> class -> class -> method     0.014266  0.313190
# 15  package -> class -> method -> snippet     0.010371  0.463472
# === Top 5 low ===
#                                short_pattern  correlation   p-value
# 6   snippet -> snippet -> snippet -> snippet    -0.034440  0.014875
# 1     package -> method -> snippet -> method    -0.033578  0.017577
# 0    package -> method -> snippet -> snippet    -0.031959  0.023829
# 16   snippet -> snippet -> method -> snippet    -0.031576  0.025567
# 8     method -> snippet -> snippet -> method    -0.029034  0.040077

# %%
n = 5 # n-gram
benchmarks = ['d4j', 'bip']
models = ['llama3', 'llama3.1', 'mistral-nemo', 'qwen2.5-coder']

for bm in benchmarks:
    for model in models:
        correlation_file = f'./correlation/autofl/{n}-gram/{bm}/{model}/correlation.csv'
        df = pd.read_csv(correlation_file)
        df['pattern'] = df['pattern'].apply(ast.literal_eval)
        df['short_pattern'] = df['pattern'].apply(shorten_pattern)

        top_5_high = df.sort_values(by='correlation', ascending=False).head(5)
        top_5_low = df.sort_values(by='correlation', ascending=True).head(5)
        print(f"=================={bm}: {model}==================")
        print("=== Top 5 high ===")
        print(top_5_high[['short_pattern', 'correlation', 'p-value']])
        print("=== Top 5 low ===")
        print(top_5_low[['short_pattern', 'correlation', 'p-value']])
# Out:
# ==================d4j: llama3==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 0    class -> method -> snippet -> snippet -> snippet     0.074302  0.000010
# 3   method -> snippet -> snippet -> snippet -> com...     0.073738  0.000012
# 8   snippet -> snippet -> snippet -> comment -> sn...     0.066395  0.000079
# 1    class -> method -> snippet -> comment -> snippet     0.064245  0.000134
# 28  method -> method -> snippet -> snippet -> snippet     0.050632  0.002620
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 4       class -> method -> method -> method -> method    -0.027285  0.105059
# 12     method -> method -> method -> method -> method    -0.020759  0.217558
# 21     class -> method -> snippet -> class -> snippet    -0.010057  0.550304
# 29     class -> method -> snippet -> comment -> class    -0.007775  0.644244
# 17  method -> snippet -> method -> snippet -> comment    -0.007775  0.644244
# ==================d4j: llama3.1==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 0    class -> method -> snippet -> snippet -> snippet     0.033347  0.047576
# 13   class -> method -> comment -> snippet -> snippet     0.032726  0.051870
# 3   snippet -> snippet -> snippet -> comment -> sn...     0.030919  0.066240
# 6   snippet -> comment -> snippet -> comment -> sn...     0.027421  0.103335
# 27   class -> method -> comment -> comment -> snippet     0.025401  0.131325
# === Top 5 low ===
#                                     short_pattern  correlation       p-value
# 5    class -> method -> method -> method -> class    -0.110059  5.502886e-11
# 8   class -> method -> method -> method -> method    -0.105268  3.620545e-10
# 7   method -> method -> method -> class -> method    -0.104466  4.921686e-10
# 17   method -> method -> class -> method -> class    -0.088622  1.335517e-07
# 9    class -> method -> method -> class -> method    -0.077969  3.520307e-06
# ==================d4j: mistral-nemo==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 6    class -> method -> snippet -> comment -> snippet     0.047584  0.004688
# 9   class -> snippet -> snippet -> snippet -> comment     0.045655  0.006668
# 22   class -> snippet -> snippet -> method -> snippet     0.041864  0.012865
# 25  method -> snippet -> comment -> snippet -> sni...     0.040234  0.016821
# 24  comment -> snippet -> snippet -> snippet -> sn...     0.039355  0.019372
# === Top 5 low ===
#                                        short_pattern  correlation   p-value
# 17     class -> method -> method -> method -> method    -0.038590  0.021857
# 13   class -> method -> method -> snippet -> snippet    -0.037360  0.026442
# 18   method -> method -> method -> method -> snippet    -0.034770  0.038856
# 16  method -> method -> method -> snippet -> snippet    -0.025629  0.127906
# 26    method -> method -> method -> method -> method    -0.021539  0.200754
# ==================d4j: qwen2.5-coder==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 11  class -> snippet -> comment -> snippet -> comment     0.072314  0.000017
# 10  snippet -> comment -> snippet -> snippet -> sn...     0.036493  0.030148
# 8   class -> snippet -> comment -> snippet -> snippet     0.036225  0.031380
# 7   method -> snippet -> snippet -> snippet -> sni...     0.033296  0.047919
# 5   snippet -> snippet -> snippet -> comment -> sn...     0.027614  0.100930
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 12     class -> method -> method -> method -> snippet    -0.031153  0.064213
# 22   class -> snippet -> snippet -> method -> snippet    -0.028437  0.091158
# 23    class -> method -> method -> snippet -> snippet    -0.028437  0.091158
# 15    class -> method -> snippet -> snippet -> method    -0.014532  0.388048
# 18  method -> snippet -> snippet -> snippet -> method    -0.012002  0.475946
# ==================bip: llama3==================
# === Top 5 high ===
#                                    short_pattern  correlation   p-value
# 3    class -> class -> class -> class -> snippet     0.064493  0.000005
# 21  class -> class -> method -> snippet -> class     0.048098  0.000669
# 10  class -> class -> class -> method -> snippet     0.042376  0.002729
# 27  class -> class -> class -> snippet -> method     0.042369  0.002733
# 20  class -> method -> class -> class -> snippet     0.036593  0.009668
# === Top 5 low ===
#                                   short_pattern  correlation   p-value
# 1   package -> class -> class -> class -> class    -0.046555  0.000993
# 6   class -> class -> class -> package -> class    -0.040946  0.003786
# 0     class -> class -> class -> class -> class    -0.039334  0.005412
# 9   class -> class -> package -> class -> class    -0.035716  0.011555
# 11  class -> package -> class -> class -> class    -0.029818  0.035013
# ==================bip: llama3.1==================
# === Top 5 high ===
#                                      short_pattern  correlation   p-value
# 8    package -> class -> class -> class -> snippet     0.056452  0.000065
# 11  package -> class -> class -> method -> snippet     0.046281  0.001062
# 7     package -> class -> class -> class -> method     0.043610  0.002040
# 4     class -> class -> class -> method -> snippet     0.040574  0.004111
# 14    class -> class -> class -> snippet -> method     0.034901  0.013586
# === Top 5 low ===
#                                   short_pattern  correlation       p-value
# 0     class -> class -> class -> class -> class    -0.119666  2.064908e-17
# 1   package -> class -> class -> class -> class    -0.098826  2.497886e-12
# 21  class -> class -> class -> class -> package    -0.058950  3.033267e-05
# 13  class -> class -> package -> class -> class    -0.058237  3.781222e-05
# 17  class -> package -> class -> class -> class    -0.055563  8.460948e-05
# ==================bip: mistral-nemo==================
# === Top 5 high ===
#                                        short_pattern  correlation   p-value
# 17   method -> method -> method -> snippet -> method     0.022948  0.104709
# 5    package -> method -> method -> method -> method     0.020346  0.150295
# 16    method -> method -> method -> method -> method     0.018249  0.196979
# 2   package -> method -> method -> method -> snippet     0.012187  0.388921
# 11   method -> method -> method -> method -> snippet     0.007747  0.583930
# === Top 5 low ===
#                                         short_pattern  correlation  \
# 0   package -> method -> snippet -> snippet -> sni...    -0.071851
# 8   method -> method -> snippet -> snippet -> snippet    -0.047029
# 3   method -> snippet -> snippet -> snippet -> sni...    -0.035014
# 10  package -> method -> snippet -> snippet -> method    -0.033793
# 14  package -> snippet -> method -> snippet -> sni...    -0.030199
#
#          p-value
# 0   3.658236e-07
# 8   8.795160e-04
# 3   1.328736e-02
# 10  1.686757e-02
# 14  3.273219e-02
# ==================bip: qwen2.5-coder==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 26  package -> snippet -> method -> method -> snippet     0.022616  0.109825
# 20   method -> method -> method -> snippet -> snippet     0.021762  0.123907
# 5    package -> method -> method -> method -> snippet     0.016390  0.246567
# 27         class -> class -> class -> class -> method     0.010874  0.442036
# 25  snippet -> method -> snippet -> snippet -> sni...     0.009997  0.479744
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 2   package -> method -> snippet -> snippet -> method    -0.032079  0.023309
# 19  snippet -> method -> snippet -> method -> snippet    -0.029164  0.039194
# 12   package -> method -> method -> snippet -> method    -0.025628  0.069981
# 0   package -> method -> snippet -> snippet -> sni...    -0.025396  0.072560
# 4   method -> snippet -> snippet -> snippet -> sni...    -0.024778  0.079786

# %%
n = 3 # n-gram
benchmarks = ['d4j', 'bip']
models = ['llama3', 'llama3.1', 'mistral-nemo', 'qwen2.5-coder']

for bm in benchmarks:
    for model in models:
        correlation_file = f'./correlation/autofl/{n}-gram/{bm}/{model}/correlation.csv'
        df = pd.read_csv(correlation_file)
        df['pattern'] = df['pattern'].apply(ast.literal_eval)
        df['short_pattern'] = df['pattern'].apply(shorten_pattern)

        top_5_high = df.sort_values(by='correlation', ascending=False).head(5)
        top_5_low = df.sort_values(by='correlation', ascending=True).head(5)
        print(f"=================={bm}: {model}==================")
        print("=== Top 5 high ===")
        print(top_5_high[['short_pattern', 'correlation', 'p-value']])
        print("=== Top 5 low ===")
        print(top_5_low[['short_pattern', 'correlation', 'p-value']])
# Out:
# ==================d4j: llama3==================
# === Top 5 high ===
#                    short_pattern  correlation       p-value
# 1   method -> snippet -> comment     0.122856  2.397947e-13
# 5  snippet -> snippet -> snippet     0.095285  1.410345e-08
# 0     class -> method -> snippet     0.092869  3.245035e-08
# 8  snippet -> comment -> snippet     0.092421  3.777672e-08
# 2   method -> snippet -> snippet     0.080004  1.942910e-06
# === Top 5 low ===
#                  short_pattern  correlation   p-value
# 29     class -> class -> class    -0.070377  0.000029
# 15    class -> class -> method    -0.058278  0.000532
# 3    class -> method -> method    -0.053512  0.001470
# 7   class -> method -> comment    -0.044874  0.007663
# 13    class -> method -> class    -0.041852  0.012890
# ==================d4j: llama3.1==================
# === Top 5 high ===
#                    short_pattern  correlation       p-value
# 0     class -> method -> snippet     0.182089  1.078132e-27
# 4     class -> method -> comment     0.116984  3.126071e-12
# 5   method -> comment -> snippet     0.101375  1.575199e-09
# 7   method -> snippet -> comment     0.088036  1.615757e-07
# 9  snippet -> snippet -> comment     0.069216  3.856885e-05
# === Top 5 low ===
#                  short_pattern  correlation       p-value
# 3    class -> method -> method    -0.183108  5.437845e-28
# 13   method -> method -> class    -0.176496  4.301735e-26
# 8   method -> method -> method    -0.175963  6.070872e-26
# 10    class -> method -> class    -0.173349  3.245958e-25
# 12   method -> class -> method    -0.149629  3.990310e-19
# ==================d4j: mistral-nemo==================
# === Top 5 high ===
#                     short_pattern  correlation       p-value
# 2     class -> snippet -> comment     0.094910  1.606844e-08
# 23  comment -> comment -> snippet     0.041632  1.337076e-02
# 13  comment -> snippet -> snippet     0.040173  1.698768e-02
# 7   snippet -> comment -> snippet     0.032531  5.328210e-02
# 6    method -> snippet -> comment     0.032254  5.534502e-02
# === Top 5 low ===
#                    short_pattern  correlation       p-value
# 8      class -> method -> method    -0.091746  4.746544e-08
# 9    method -> method -> snippet    -0.075729  6.661833e-06
# 4   method -> snippet -> snippet    -0.060035  3.584951e-04
# 14    method -> method -> method    -0.047870  4.444772e-03
# 3    class -> snippet -> snippet    -0.041730  1.315420e-02
# ==================d4j: qwen2.5-coder==================
# === Top 5 high ===
#                     short_pattern  correlation       p-value
# 3     class -> snippet -> comment     0.169375  3.946573e-24
# 5   snippet -> comment -> snippet     0.091450  5.242654e-08
# 17  comment -> snippet -> comment     0.052761  1.713707e-03
# 13  comment -> snippet -> snippet     0.044959  7.549217e-03
# 1     class -> snippet -> snippet     0.028434  9.119661e-02
# === Top 5 low ===
#                   short_pattern  correlation   p-value
# 0    class -> method -> snippet    -0.073297  0.000013
# 7     class -> method -> method    -0.061637  0.000248
# 10   class -> snippet -> method    -0.048565  0.003900
# 12  method -> method -> snippet    -0.046619  0.005600
# 15  method -> snippet -> method    -0.039158  0.019987
# ==================bip: llama3==================
# === Top 5 high ===
#                   short_pattern  correlation       p-value
# 3     class -> class -> snippet     0.087985  4.623577e-10
# 8    class -> method -> snippet     0.054821  1.053249e-04
# 20   class -> snippet -> method     0.048098  6.694531e-04
# 17  package -> method -> method     0.043849  1.928468e-03
# 10  package -> class -> snippet     0.043685  2.005480e-03
# === Top 5 low ===
#                   short_pattern  correlation   p-value
# 0       class -> class -> class    -0.046300  0.001059
# 5     class -> package -> class    -0.036760  0.009341
# 4     class -> class -> package    -0.032016  0.023595
# 1     package -> class -> class    -0.029265  0.038538
# 15  package -> package -> class    -0.013212  0.350318
# ==================bip: llama3.1==================
# === Top 5 high ===
#                     short_pattern  correlation       p-value
# 3    package -> method -> snippet     0.101701  5.668611e-13
# 13   package -> snippet -> method     0.069572  8.469885e-07
# 5      class -> method -> snippet     0.056268  6.865072e-05
# 4       class -> class -> snippet     0.049833  4.234223e-04
# 10  package -> snippet -> snippet     0.048295  6.352268e-04
# === Top 5 low ===
#                 short_pattern  correlation   p-value
# 16  class -> package -> class    -0.067693  0.000002
# 0     class -> class -> class    -0.062979  0.000008
# 12  class -> class -> package    -0.059565  0.000025
# 8    class -> method -> class    -0.051411  0.000276
# 9    method -> class -> class    -0.034589  0.014448
# ==================bip: mistral-nemo==================
# === Top 5 high ===
#                    short_pattern  correlation   p-value
# 6     method -> method -> method     0.017343  0.220151
# 5  package -> snippet -> snippet     0.014587  0.302408
# 0   package -> method -> snippet     0.014527  0.304427
# 3    method -> method -> snippet    -0.017066  0.227623
# 2    package -> method -> method    -0.021053  0.136633
# === Top 5 low ===
#                     short_pattern  correlation       p-value
# 4   snippet -> snippet -> snippet    -0.069869  7.602505e-07
# 1    method -> snippet -> snippet    -0.067360  1.867033e-06
# 10   snippet -> snippet -> method    -0.053420  1.573930e-04
# 7     method -> snippet -> method    -0.042358  2.737648e-03
# 9    package -> snippet -> method    -0.038497  6.479954e-03
# ==================bip: qwen2.5-coder==================
# === Top 5 high ===
#                    short_pattern  correlation   p-value
# 14    class -> method -> snippet     0.014344  0.310547
# 16      class -> class -> method     0.014145  0.317325
# 8   package -> snippet -> method     0.012363  0.382095
# 27  package -> package -> method     0.010874  0.442036
# 23      class -> method -> class     0.010874  0.442036
# === Top 5 low ===
#                     short_pattern  correlation   p-value
# 3     method -> snippet -> method    -0.044592  0.001611
# 4   snippet -> snippet -> snippet    -0.040002  0.004670
# 10   snippet -> snippet -> method    -0.036938  0.008997
# 1    method -> snippet -> snippet    -0.035887  0.011155
# 7    snippet -> method -> snippet    -0.030762  0.029615

# %%
name_mapping = {
    'get_covered_packages_pass': 'package_pass',
    'get_failing_tests_covered_classes_pass': 'class_pass',
    'get_failing_tests_covered_methods_for_class_pass': 'method_pass',
    'get_code_snippet_pass': 'snippet_pass',
    'get_comments_pass': 'comment_pass',
    'get_covered_packages_fail': 'package_fail',
    'get_failing_tests_covered_classes_fail': 'class_fail',
    'get_failing_tests_covered_methods_for_class_fail': 'method_fail',
    'get_code_snippet_fail': 'snippet_fail',
    'get_comments_fail': 'comment_fail'
}

def shorten_pattern(pattern_tuple):
    """Convert long function names to short versions"""
    return ' -> '.join([name_mapping.get(func, func) for func in pattern_tuple])

# %%
n = 4 # n-gram
benchmarks = ['d4j', 'bip']
models = ['llama3', 'llama3.1', 'mistral-nemo', 'qwen2.5-coder']

for bm in benchmarks:
    for model in models:
        correlation_file = f'./correlation/autofl/{n}-gram/{bm}/{model}/correlation_call_ok.csv'
        df = pd.read_csv(correlation_file)
        df['pattern'] = df['pattern'].apply(ast.literal_eval)
        df['short_pattern'] = df['pattern'].apply(shorten_pattern)

        top_5_high = df.sort_values(by='correlation', ascending=False).head(5)
        top_5_low = df.sort_values(by='correlation', ascending=True).head(5)
        print(f"=================={bm}: {model}==================")
        print("=== Top 5 high ===")
        print(top_5_high[['short_pattern', 'correlation', 'p-value']])
        print("=== Top 5 low ===")
        print(top_5_low[['short_pattern', 'correlation', 'p-value']])
# Out:
# ==================d4j: llama3==================
# === Top 5 high ===
#                                         short_pattern  correlation  \
# 0   class_pass -> method_pass -> snippet_pass -> c...     0.159393
# 4   method_pass -> snippet_fail -> snippet_fail ->...     0.080145
# 1   class_pass -> method_pass -> snippet_fail -> s...     0.077929
# 9   snippet_fail -> snippet_fail -> snippet_fail -...     0.064590
# 10  snippet_fail -> snippet_fail -> comment_fail -...     0.064590
#
#          p-value
# 0   1.607227e-21
# 4   1.863531e-06
# 1   3.561241e-06
# 9   1.229410e-04
# 10  1.229410e-04
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 20  class_pass -> method_fail -> comment_pass -> s...    -0.048397  0.004026
# 3   class_pass -> method_fail -> method_fail -> me...    -0.046964  0.005257
# 6   method_fail -> method_fail -> method_fail -> m...    -0.028633  0.088958
# 5   class_pass -> method_fail -> snippet_pass -> c...    -0.027700  0.099869
# 26  class_pass -> method_fail -> method_fail -> cl...    -0.027297  0.104904
# ==================d4j: llama3.1==================
# === Top 5 high ===
#                                         short_pattern  correlation  \
# 1   class_pass -> method_pass -> snippet_pass -> c...     0.149824
# 2   class_pass -> method_pass -> comment_pass -> s...     0.109135
# 7   class_pass -> method_pass -> snippet_pass -> s...     0.081285
# 16  class_pass -> method_fail -> method_pass -> sn...     0.047721
# 18  class_pass -> method_pass -> comment_fail -> s...     0.041651
#
#          p-value
# 1   3.587258e-19
# 2   7.966797e-11
# 7   1.326468e-06
# 16  4.569541e-03
# 18  1.332963e-02
# === Top 5 low ===
#                                         short_pattern  correlation  \
# 5   class_pass -> method_fail -> method_fail -> me...    -0.170206
# 11  method_fail -> method_fail -> method_fail -> c...    -0.136221
# 8   method_fail -> method_fail -> class_pass -> me...    -0.130489
# 12  class_pass -> method_fail -> method_fail -> cl...    -0.110574
# 15  method_fail -> class_pass -> method_fail -> cl...    -0.106612
#
#          p-value
# 5   2.351556e-24
# 11  4.347903e-16
# 8   7.060795e-15
# 12  4.473345e-11
# 15  2.151621e-10
# ==================d4j: mistral-nemo==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 3   class_pass -> method_pass -> snippet_pass -> c...     0.057052  0.000696
# 11  snippet_fail -> comment_fail -> snippet_fail -...     0.047772  0.004527
# 14  snippet_fail -> snippet_fail -> snippet_fail -...     0.038788  0.021191
# 9   snippet_fail -> snippet_fail -> comment_fail -...     0.032691  0.052120
# 10  snippet_fail -> snippet_fail -> snippet_fail -...     0.016679  0.321846
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 6   class_pass -> method_fail -> method_fail -> sn...    -0.062756  0.000191
# 8   class_pass -> method_fail -> method_fail -> me...    -0.046918  0.005301
# 12  class_pass -> method_fail -> snippet_pass -> c...    -0.042938  0.010729
# 18  class_pass -> method_fail -> snippet_pass -> s...    -0.040943  0.014986
# 20  method_fail -> method_fail -> method_fail -> m...    -0.038590  0.021857
# ==================d4j: qwen2.5-coder==================
# === Top 5 high ===
#                                         short_pattern  correlation  \
# 0   class_pass -> snippet_pass -> comment_pass -> ...     0.112186
# 25  snippet_pass -> comment_pass -> snippet_pass -...     0.071919
# 6   class_pass -> method_pass -> snippet_fail -> s...     0.065284
# 10  method_pass -> snippet_fail -> snippet_fail ->...     0.058456
# 4   snippet_fail -> snippet_fail -> snippet_fail -...     0.053867
#
#          p-value
# 0   2.323208e-11
# 25  1.894335e-05
# 6   1.038036e-04
# 10  5.111224e-04
# 4   1.366614e-03
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 12  class_pass -> method_fail -> method_fail -> me...    -0.045099  0.007364
# 11  class_pass -> method_fail -> snippet_pass -> s...    -0.041772  0.013063
# 14  class_pass -> method_fail -> snippet_fail -> s...    -0.038349  0.022698
# 23  class_pass -> method_fail -> method_fail -> sn...    -0.038265  0.022995
# 26  class_pass -> snippet_fail -> snippet_fail -> ...    -0.037000  0.027930
# ==================bip: llama3==================
# === Top 5 high ===
#                                         short_pattern  correlation  \
# 3   class_fail -> class_fail -> class_fail -> snip...     0.083212
# 25  class_fail -> method_pass -> class_fail -> cla...     0.056320
# 15  package_pass -> class_fail -> class_fail -> sn...     0.054330
# 10  class_fail -> class_fail -> snippet_pass -> cl...     0.050423
# 9   class_fail -> class_fail -> class_fail -> meth...     0.045300
#
#          p-value
# 3   3.812794e-09
# 25  6.771159e-05
# 15  1.214243e-04
# 10  3.617884e-04
# 9   1.356798e-03
# === Top 5 low ===
#                                        short_pattern  correlation   p-value
# 0  class_fail -> class_fail -> class_fail -> clas...    -0.047422  0.000797
# 1  package_pass -> class_fail -> class_fail -> cl...    -0.045503  0.001291
# 5  class_fail -> class_fail -> package_pass -> cl...    -0.044305  0.001729
# 4  class_fail -> class_fail -> class_fail -> pack...    -0.031299  0.026903
# 2  class_fail -> class_fail -> class_fail -> meth...    -0.031051  0.028137
# ==================bip: llama3.1==================
# === Top 5 high ===
#                                         short_pattern  correlation  \
# 3   class_fail -> class_fail -> class_fail -> snip...     0.091111
# 19  package_pass -> method_pass -> snippet_pass ->...     0.086200
# 8   class_fail -> class_fail -> method_pass -> sni...     0.071126
# 4   class_fail -> class_fail -> class_fail -> meth...     0.068692
# 23  package_pass -> class_fail -> class_fail -> me...     0.052336
#
#          p-value
# 3   1.086923e-10
# 19  1.027181e-09
# 8   4.791784e-07
# 4   1.163208e-06
# 23  2.136335e-04
# === Top 5 low ===
#                                         short_pattern  correlation  \
# 0   class_fail -> class_fail -> class_fail -> clas...    -0.101930
# 9   class_fail -> class_fail -> package_pass -> cl...    -0.064560
# 14  class_fail -> package_pass -> class_fail -> cl...    -0.062539
# 1   package_pass -> class_fail -> class_fail -> cl...    -0.059296
# 2   class_fail -> class_fail -> class_fail -> meth...    -0.051766
#
#          p-value
# 0   5.028563e-13
# 9   4.907156e-06
# 14  9.626653e-06
# 1   2.722708e-05
# 2   2.502925e-04
# ==================bip: mistral-nemo==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 8   package_pass -> method_pass -> snippet_pass ->...     0.027868  0.048782
# 7   method_fail -> method_fail -> method_fail -> s...     0.023726  0.093451
# 22  package_pass -> snippet_fail -> snippet_fail -...     0.018046  0.202027
# 2   package_pass -> method_fail -> method_fail -> ...     0.017558  0.214483
# 5   package_pass -> method_fail -> snippet_pass ->...     0.015828  0.263151
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 3   package_pass -> method_fail -> snippet_fail ->...    -0.061154  0.000015
# 13  method_fail -> method_fail -> snippet_fail -> ...    -0.052500  0.000204
# 10  method_fail -> snippet_fail -> snippet_fail ->...    -0.051739  0.000252
# 20  method_fail -> snippet_fail -> snippet_fail ->...    -0.043453  0.002117
# 4   package_pass -> method_fail -> method_fail -> ...    -0.043406  0.002141
# ==================bip: qwen2.5-coder==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 17  method_fail -> method_fail -> snippet_pass -> ...     0.044716  0.001563
# 22  package_pass -> method_pass -> snippet_pass ->...     0.032225  0.022687
# 7   package_pass -> method_pass -> snippet_pass ->...     0.030139  0.033083
# 26  package_pass -> method_fail -> method_pass -> ...     0.028805  0.041675
# 14  method_fail -> method_fail -> method_fail -> s...     0.020023  0.156874
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 5   package_pass -> method_fail -> snippet_fail ->...    -0.048745  0.000565
# 1   package_pass -> method_fail -> snippet_fail ->...    -0.047979  0.000689
# 9   package_pass -> method_fail -> method_fail -> ...    -0.043762  0.001967
# 25  method_fail -> snippet_fail -> snippet_fail ->...    -0.040421  0.004255
# 2   package_pass -> method_fail -> snippet_fail ->...    -0.037061  0.008772

# %%
n = 5 # n-gram
benchmarks = ['d4j', 'bip']
models = ['llama3', 'llama3.1', 'mistral-nemo', 'qwen2.5-coder']

for bm in benchmarks:
    for model in models:
        correlation_file = f'./correlation/autofl/{n}-gram/{bm}/{model}/correlation_call_ok.csv'
        df = pd.read_csv(correlation_file)
        df['pattern'] = df['pattern'].apply(ast.literal_eval)
        df['short_pattern'] = df['pattern'].apply(shorten_pattern)

        top_5_high = df.sort_values(by='correlation', ascending=False).head(5)
        top_5_low = df.sort_values(by='correlation', ascending=True).head(5)
        print(f"=================={bm}: {model}==================")
        print("=== Top 5 high ===")
        print(top_5_high[['short_pattern', 'correlation', 'p-value']])
        print("=== Top 5 low ===")
        print(top_5_low[['short_pattern', 'correlation', 'p-value']])
# Out:
# ==================d4j: llama3==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 0   class_pass -> method_pass -> snippet_fail -> s...     0.075339  0.000007
# 5   snippet_fail -> snippet_fail -> snippet_fail -...     0.065386  0.000101
# 18  method_pass -> snippet_pass -> snippet_pass ->...     0.061154  0.000277
# 2   class_pass -> method_pass -> snippet_pass -> c...     0.060630  0.000313
# 4   method_pass -> snippet_fail -> snippet_fail ->...     0.054144  0.001290
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 1   class_pass -> method_fail -> method_fail -> me...    -0.027720  0.099621
# 9   method_fail -> method_fail -> method_fail -> m...    -0.019196  0.254204
# 27  class_pass -> method_pass -> snippet_fail -> c...    -0.015715  0.350607
# 11  class_pass -> method_fail -> method_fail -> me...    -0.006587  0.695630
# 14  class_pass -> method_fail -> method_fail -> sn...    -0.004601  0.784667
# ==================d4j: llama3.1==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 29  method_pass -> snippet_fail -> snippet_fail ->...     0.040973  0.014912
# 24  class_pass -> method_pass -> comment_fail -> s...     0.037972  0.024067
# 16  class_pass -> method_pass -> snippet_pass -> c...     0.035828  0.033286
# 1   class_pass -> method_pass -> snippet_fail -> s...     0.032670  0.052272
# 22  snippet_fail -> snippet_fail -> snippet_fail -...     0.023388  0.164747
# === Top 5 low ===
#                                         short_pattern  correlation  \
# 4   class_pass -> method_fail -> method_fail -> me...    -0.109144
# 6   method_fail -> method_fail -> method_fail -> c...    -0.102544
# 8   class_pass -> method_fail -> method_fail -> me...    -0.097948
# 10  method_fail -> method_fail -> class_pass -> me...    -0.088069
# 9   class_pass -> method_fail -> method_fail -> cl...    -0.080949
#
#          p-value
# 4   7.935741e-11
# 6   1.018629e-09
# 8   5.495918e-09
# 10  1.598269e-07
# 9   1.466792e-06
# ==================d4j: mistral-nemo==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 29  class_pass -> snippet_fail -> snippet_fail -> ...     0.050996  0.002439
# 15  snippet_fail -> comment_fail -> snippet_fail -...     0.048390  0.004032
# 18  class_pass -> method_pass -> snippet_fail -> c...     0.041864  0.012865
# 23  snippet_fail -> snippet_fail -> snippet_fail -...     0.039355  0.019372
# 7   class_pass -> snippet_fail -> snippet_fail -> ...     0.036262  0.031206
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 13  class_pass -> method_fail -> method_fail -> me...    -0.038590  0.021857
# 17  method_fail -> method_fail -> method_fail -> m...    -0.033401  0.047218
# 11  class_pass -> method_fail -> method_fail -> sn...    -0.028914  0.085863
# 20  class_pass -> snippet_fail -> snippet_fail -> ...    -0.023918  0.155390
# 22  class_pass -> method_fail -> snippet_pass -> s...    -0.023598  0.160990
# ==================d4j: qwen2.5-coder==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 8   class_pass -> snippet_pass -> comment_pass -> ...     0.078879  0.000003
# 1   class_pass -> method_pass -> snippet_fail -> s...     0.059040  0.000449
# 9   method_pass -> snippet_fail -> snippet_fail ->...     0.055411  0.000989
# 16  class_pass -> snippet_pass -> comment_pass -> ...     0.042626  0.011314
# 21  snippet_fail -> comment_fail -> snippet_fail -...     0.042626  0.011314
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 7   class_pass -> method_fail -> method_fail -> me...    -0.034600  0.039819
# 14  class_pass -> method_fail -> snippet_pass -> s...    -0.023909  0.155545
# 24  class_pass -> method_pass -> snippet_pass -> s...    -0.022625  0.178961
# 29  class_pass -> snippet_fail -> method_fail -> s...    -0.022625  0.178961
# 19  class_pass -> method_fail -> snippet_pass -> s...    -0.015159  0.367914
# ==================bip: llama3==================
# === Top 5 high ===
#                                         short_pattern  correlation  \
# 3   class_fail -> class_fail -> class_fail -> clas...     0.074328
# 24  class_fail -> class_fail -> method_pass -> cla...     0.056320
# 11  class_fail -> class_fail -> class_fail -> snip...     0.049608
# 12  class_fail -> class_fail -> class_fail -> clas...     0.046452
# 27  class_fail -> method_fail -> class_fail -> cla...     0.041828
#
#          p-value
# 3   1.431255e-07
# 24  6.771159e-05
# 11  4.501890e-04
# 12  1.018834e-03
# 27  3.096684e-03
# === Top 5 low ===
#                                        short_pattern  correlation   p-value
# 1  package_pass -> class_fail -> class_fail -> cl...    -0.046555  0.000993
# 7  class_fail -> class_fail -> class_fail -> pack...    -0.040946  0.003786
# 0  class_fail -> class_fail -> class_fail -> clas...    -0.039334  0.005412
# 8  class_fail -> class_fail -> package_pass -> cl...    -0.035716  0.011555
# 2  class_fail -> class_fail -> class_fail -> clas...    -0.029876  0.034659
# ==================bip: llama3.1==================
# === Top 5 high ===
#                                         short_pattern  correlation  \
# 13  package_pass -> class_fail -> class_fail -> cl...     0.078487
# 3   class_fail -> class_fail -> class_fail -> clas...     0.060699
# 29  package_pass -> class_fail -> class_fail -> me...     0.054591
# 8   class_fail -> class_fail -> class_fail -> meth...     0.053341
# 4   class_fail -> class_fail -> class_fail -> clas...     0.048958
#
#          p-value
# 13  2.743389e-08
# 3   1.747324e-05
# 29  1.124203e-04
# 8   1.609395e-04
# 4   5.339943e-04
# === Top 5 low ===
#                                         short_pattern  correlation  \
# 0   class_fail -> class_fail -> class_fail -> clas...    -0.119666
# 1   package_pass -> class_fail -> class_fail -> cl...    -0.098826
# 2   class_fail -> class_fail -> class_fail -> clas...    -0.061912
# 14  class_fail -> class_fail -> package_pass -> cl...    -0.058237
# 20  class_fail -> class_fail -> class_fail -> clas...    -0.055563
#
#          p-value
# 0   2.064908e-17
# 1   2.497886e-12
# 2   1.181826e-05
# 14  3.781222e-05
# 20  8.460948e-05
# ==================bip: mistral-nemo==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 0   package_pass -> method_fail -> method_fail -> ...     0.032324  0.022273
# 24  package_pass -> method_fail -> snippet_fail ->...     0.028448  0.044278
# 12  method_fail -> method_fail -> method_fail -> m...     0.024544  0.082682
# 15  method_fail -> method_fail -> method_fail -> m...     0.018249  0.196979
# 4   package_pass -> method_fail -> method_fail -> ...     0.014623  0.301243
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 3   package_pass -> method_fail -> method_fail -> ...    -0.047325  0.000816
# 22  method_fail -> method_fail -> snippet_fail -> ...    -0.037565  0.007895
# 8   package_pass -> method_fail -> snippet_fail ->...    -0.037224  0.008479
# 1   package_pass -> method_fail -> snippet_fail ->...    -0.036034  0.010828
# 19  package_pass -> method_fail -> snippet_fail ->...    -0.031545  0.025709
# ==================bip: qwen2.5-coder==================
# === Top 5 high ===
#                                         short_pattern  correlation   p-value
# 7   package_pass -> method_fail -> method_fail -> ...     0.033153  0.019062
# 17  package_pass -> method_fail -> snippet_pass ->...     0.024401  0.084483
# 24  method_pass -> snippet_pass -> snippet_fail ->...     0.022616  0.109825
# 10  package_pass -> method_pass -> snippet_pass ->...     0.018842  0.182813
# 1   package_pass -> method_fail -> method_fail -> ...     0.017472  0.216746
# === Top 5 low ===
#                                         short_pattern  correlation   p-value
# 14  package_pass -> method_fail -> method_fail -> ...    -0.035740  0.011491
# 5   package_pass -> method_fail -> snippet_fail ->...    -0.035740  0.011491
# 19  package_pass -> method_fail -> snippet_fail ->...    -0.030358  0.031825
# 8   package_pass -> method_fail -> snippet_fail ->...    -0.028120  0.046783
# 15  package_pass -> method_fail -> snippet_fail ->...    -0.021418  0.129961

# %%
n = 3 # n-gram
benchmarks = ['d4j', 'bip']
models = ['llama3', 'llama3.1', 'mistral-nemo', 'qwen2.5-coder']

for bm in benchmarks:
    for model in models:
        correlation_file = f'./correlation/autofl/{n}-gram/{bm}/{model}/correlation_call_ok.csv'
        df = pd.read_csv(correlation_file)
        df['pattern'] = df['pattern'].apply(ast.literal_eval)
        df['short_pattern'] = df['pattern'].apply(shorten_pattern)

        top_5_high = df.sort_values(by='correlation', ascending=False).head(5)
        top_5_low = df.sort_values(by='correlation', ascending=True).head(5)
        print(f"=================={bm}: {model}==================")
        print("=== Top 5 high ===")
        print(top_5_high[['short_pattern', 'correlation', 'p-value']])
        print("=== Top 5 low ===")
        print(top_5_low[['short_pattern', 'correlation', 'p-value']])
# Out:
# ==================d4j: llama3==================
# === Top 5 high ===
#                                    short_pattern  correlation       p-value
# 2    method_pass -> snippet_pass -> comment_pass     0.163709  1.252243e-22
# 0      class_pass -> method_pass -> snippet_pass     0.119888  8.918609e-13
# 6   snippet_fail -> snippet_fail -> snippet_fail     0.091953  4.426208e-08
# 7    method_pass -> snippet_fail -> snippet_fail     0.080755  1.554491e-06
# 13  snippet_fail -> comment_fail -> snippet_fail     0.070397  2.835498e-05
# === Top 5 low ===
#                                   short_pattern  correlation   p-value
# 4     class_pass -> method_fail -> snippet_pass    -0.078831  0.000003
# 17    class_pass -> method_fail -> comment_pass    -0.076924  0.000005
# 25      class_pass -> method_fail -> class_pass    -0.055296  0.001014
# 3      class_pass -> method_fail -> method_fail    -0.052303  0.001880
# 27  method_fail -> comment_pass -> snippet_pass    -0.043540  0.009676
# ==================d4j: llama3.1==================
# === Top 5 high ===
#                                   short_pattern  correlation       p-value
# 0     class_pass -> method_pass -> snippet_pass     0.232501  1.533725e-44
# 5   method_pass -> snippet_pass -> comment_pass     0.133507  1.651965e-15
# 2     class_pass -> method_pass -> comment_pass     0.130324  7.635281e-15
# 7   method_pass -> comment_pass -> snippet_pass     0.107721  1.394169e-10
# 15  method_pass -> snippet_pass -> snippet_pass     0.069619  3.474874e-05
# === Top 5 low ===
#                                 short_pattern  correlation       p-value
# 3    class_pass -> method_fail -> method_fail    -0.217397  4.988771e-39
# 11   method_fail -> method_fail -> class_pass    -0.175515  8.110320e-26
# 9   method_fail -> method_fail -> method_fail    -0.170531  1.919829e-24
# 6     class_pass -> method_fail -> class_pass    -0.169653  3.319748e-24
# 12   method_fail -> class_pass -> method_fail    -0.155237  1.755549e-20
# ==================d4j: mistral-nemo==================
# === Top 5 high ===
#                                    short_pattern  correlation       p-value
# 2     class_pass -> snippet_pass -> comment_pass     0.106191  2.534568e-10
# 0      class_pass -> method_pass -> snippet_pass     0.088079  1.593420e-07
# 8    method_pass -> snippet_pass -> comment_pass     0.057052  6.957817e-04
# 19  comment_fail -> snippet_fail -> snippet_fail     0.054944  1.091763e-03
# 14  snippet_fail -> comment_fail -> snippet_fail     0.046372  5.857228e-03
# === Top 5 low ===
#                                   short_pattern  correlation       p-value
# 4     class_pass -> method_fail -> snippet_pass    -0.132129  3.218931e-15
# 10     class_pass -> method_fail -> method_fail    -0.089726  9.303516e-08
# 13   method_fail -> method_fail -> snippet_pass    -0.069235  3.838596e-05
# 12   class_pass -> snippet_fail -> snippet_pass    -0.054620  1.168563e-03
# 25  method_fail -> snippet_pass -> snippet_fail    -0.048300  4.100434e-03
# ==================d4j: qwen2.5-coder==================
# === Top 5 high ===
#                                    short_pattern  correlation       p-value
# 0     class_pass -> snippet_pass -> comment_pass     0.179069  8.011811e-27
# 9   snippet_pass -> comment_pass -> snippet_pass     0.119830  9.145358e-13
# 13   method_pass -> snippet_fail -> snippet_fail     0.056202  8.359128e-04
# 10     class_pass -> method_pass -> snippet_fail     0.053326  1.527257e-03
# 7   snippet_fail -> comment_fail -> snippet_fail     0.052453  1.823986e-03
# === Top 5 low ===
#                                    short_pattern  correlation       p-value
# 3      class_pass -> method_fail -> snippet_pass    -0.105253  3.640518e-10
# 12     class_pass -> method_fail -> snippet_fail    -0.069760  3.349643e-05
# 11      class_pass -> method_fail -> method_fail    -0.068909  4.175333e-05
# 22    method_fail -> method_fail -> snippet_pass    -0.052775  1.708965e-03
# 27  snippet_pass -> snippet_fail -> snippet_fail    -0.050313  2.788433e-03
# ==================bip: llama3==================
# === Top 5 high ===
#                                 short_pattern  correlation       p-value
# 3    class_fail -> class_fail -> snippet_pass     0.106074  5.511887e-14
# 16  class_fail -> method_pass -> snippet_pass     0.067768  1.620353e-06
# 8     class_fail -> class_fail -> method_pass     0.058144  3.897439e-05
# 26    method_pass -> class_fail -> class_fail     0.056320  6.771159e-05
# 9    class_fail -> snippet_pass -> class_fail     0.053167  1.693588e-04
# === Top 5 low ===
#                               short_pattern  correlation   p-value
# 0    class_fail -> class_fail -> class_fail    -0.046300  0.001059
# 5  class_fail -> package_pass -> class_fail    -0.036760  0.009341
# 4  class_fail -> class_fail -> package_pass    -0.031719  0.024921
# 2   class_fail -> class_fail -> method_fail    -0.029364  0.037886
# 1  package_pass -> class_fail -> class_fail    -0.029265  0.038538
# ==================bip: llama3.1==================
# === Top 5 high ===
#                                   short_pattern  correlation       p-value
# 4   package_pass -> method_pass -> snippet_pass     0.141445  9.211908e-24
# 3      class_fail -> class_fail -> snippet_pass     0.107892  2.016486e-14
# 21  package_pass -> snippet_pass -> method_pass     0.096099  9.808752e-12
# 5       class_fail -> class_fail -> method_pass     0.086409  9.360015e-10
# 19  method_pass -> snippet_pass -> snippet_pass     0.077962  3.394765e-08
# === Top 5 low ===
#                                short_pattern  correlation   p-value
# 14  class_fail -> package_pass -> class_fail    -0.067693  0.000002
# 0     class_fail -> class_fail -> class_fail    -0.062979  0.000008
# 12  class_fail -> class_fail -> package_pass    -0.055966  0.000075
# 2    class_fail -> class_fail -> method_fail    -0.050701  0.000335
# 7    class_fail -> method_fail -> class_fail    -0.049796  0.000428
# ==================bip: mistral-nemo==================
# === Top 5 high ===
#                                    short_pattern  correlation   p-value
# 1    package_pass -> method_pass -> snippet_pass     0.067440  0.000002
# 9   package_pass -> snippet_fail -> snippet_pass     0.038554  0.006400
# 0    package_pass -> method_fail -> snippet_pass     0.031993  0.023681
# 19   method_pass -> snippet_pass -> snippet_pass     0.028858  0.041300
# 18  package_pass -> snippet_pass -> snippet_pass     0.027630  0.050743
# === Top 5 low ===
#                                    short_pattern  correlation       p-value
# 7    method_fail -> snippet_fail -> snippet_fail    -0.082292  5.630597e-09
# 3    package_pass -> method_fail -> snippet_fail    -0.074998  1.100559e-07
# 11  snippet_fail -> snippet_fail -> snippet_fail    -0.067932  1.525252e-06
# 23   snippet_fail -> snippet_fail -> method_fail    -0.057357  4.947841e-05
# 25   package_pass -> snippet_fail -> method_fail    -0.054302  1.222182e-04
# ==================bip: qwen2.5-coder==================
# === Top 5 high ===
#                                    short_pattern  correlation       p-value
# 1    package_pass -> method_pass -> snippet_pass     0.076798  5.415353e-08
# 8   package_pass -> snippet_pass -> snippet_pass     0.050063  3.981719e-04
# 24   package_pass -> snippet_pass -> method_pass     0.049374  4.785245e-04
# 0    package_pass -> method_fail -> snippet_pass     0.045150  1.406060e-03
# 21   package_pass -> snippet_pass -> method_fail     0.043161  2.268544e-03
# === Top 5 low ===
#                                   short_pattern  correlation       p-value
# 2   package_pass -> method_fail -> snippet_fail    -0.095687  1.202048e-11
# 9   method_fail -> snippet_fail -> snippet_fail    -0.061245  1.466521e-05
# 4    method_fail -> snippet_fail -> method_fail    -0.053334  1.612784e-04
# 14  package_pass -> method_pass -> snippet_fail    -0.048481  6.051711e-04
# 20   method_fail -> method_fail -> snippet_fail    -0.044124  1.803826e-03
